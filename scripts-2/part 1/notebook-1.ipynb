# %% [markdown]
# # Notebook 1

# %% [markdown]
# ## Задание 1
#
# Из БВ FRED загрузите ряд `MORTGAGE30US` ([ссылка](https://fred.stlouisfed.org/series/MORTGAGE30US)) c **2010-01-01** по **2025-12-31**. Для **первой разности** этого ряда подгоните модель AR(2)-EGARCH(1, 0, 1). По подогнанной модели постройте прогноз на 1 период вперёд. В ответе укажите значение прогноза, умноженного на **1000**. Ответ округлите до 3-х десятичных знаков.
#
# Прогноз на 1 период =

# %%
import warnings
warnings.filterwarnings("ignore")

from pandas_datareader.data import DataReader
from arch import arch_model

# 1. Загружаем ряд
x = DataReader(
    "MORTGAGE30US",
    "fred",
    start="2010-01-01",
    end="2025-12-31",
)["MORTGAGE30US"].dropna()

# 2. Первая разность
y = x.diff().dropna()

# 3. AR(2)-EGARCH(1, 0, 1)
model = arch_model(
    y,
    mean="ARX",
    lags=2,
    vol="EGARCH",
    p=1,
    o=0,
    q=1,
    dist="normal",
    rescale=False,
)

res = model.fit(disp="off")

# 4. Прогноз на 1 период вперед
forecast = res.forecast(horizon=1, reindex=False)
f1 = forecast.mean.iloc[-1, 0]

answer = f1 * 1000
print(round(answer, 3))
# Out:
# -9.36

# %% [markdown]
# ## Задание 2
#
# Из БВ FRED загрузите ряд `WAAA` ([ссылка](https://fred.stlouisfed.org/series/WAAA)) c **2010-01-01** по **2025-12-31**. Для **первой разности** этого ряда подгоните модель AR(3)-GARCH(1, 1, 2) c λ=2. По подогнанной модели постройте прогноз на 2 период вперёд. В ответе укажите значение прогноза, умноженного на **1000**. Ответ округлите до 3-х десятичных знаков.
#
# Прогноз на 1 период =
#
# Прогноз на 2 период =

# %%
import warnings
warnings.filterwarnings("ignore")

from pandas_datareader.data import DataReader
from arch import arch_model

x = DataReader(
    "WAAA",
    "fred",
    start="2010-01-01",
    end="2025-12-31",
)["WAAA"].dropna()

y = x.diff().dropna()

model = arch_model(
    y,
    mean="ARX",
    lags=3,
    vol="GARCH",
    p=1,
    o=1,
    q=2,
    power=2.0,      # lambda = 2
    dist="normal",
    rescale=False,
)

res = model.fit(disp="off")

forecast = res.forecast(horizon=2, reindex=False)
means = forecast.mean.iloc[-1]

h1 = means.iloc[0] * 1000
h2 = means.iloc[1] * 1000

print(round(h1, 3))
print(round(h2, 3))
# Out:
# -3.215
# 2.102

# %% [markdown]
# ## Задание 4
#
# Из БВ FRED загрузите ряд `MORTGAGE15US` ([ссылка](https://fred.stlouisfed.org/series/MORTGAGE15US)) c **2010-01-01** по **2025-12-31**. Для **первой разности** этого ряда подгоните модель AR(1)-GARCH(1, 1, 1) c λ=1 и укажите её коэффициенты. Ответ округлите до 3-х десятичных знаков.
#
# α1 =
#
# β1 =

# %%
import warnings
warnings.filterwarnings("ignore")

from pandas_datareader.data import DataReader
from arch import arch_model

x = DataReader(
    "MORTGAGE15US",
    "fred",
    start="2010-01-01",
    end="2025-12-31",
)["MORTGAGE15US"].dropna()

y = x.diff().dropna()

model = arch_model(
    y,
    mean="ARX",
    lags=1,
    vol="GARCH",
    p=1,
    o=1,
    q=1,
    power=1.0,      # lambda = 1
    dist="normal",
    rescale=False,
)

res = model.fit(disp="off")

print(res.params)

alpha1 = res.params["alpha[1]"]
beta1 = res.params["beta[1]"]

print(round(alpha1, 3))
print(round(beta1, 3))
# Out:
# Const           -0.003079
# MORT...5US[1]    0.084506
# omega            0.003065
# alpha[1]         0.161746
# gamma[1]        -0.065217
# beta[1]          0.864101
# Name: params, dtype: float64
# 0.162
# 0.864

# %% [markdown]
# ## Задание 5
#
# Из БВ FRED загрузите ряд `MORTGAGE30US` ([ссылка](https://fred.stlouisfed.org/series/MORTGAGE30US)) c **2010-01-01** по **2025-12-31**. Для **первой разности** этого ряда подгоните модель AR(2)-EGARCH(1, 0, 1) и укажите её коэффициенты. Ответ округлите до 3-х десятичных знаков.
#
# α1 =
#
# β1 =

# %%
import warnings
warnings.filterwarnings("ignore")

from pandas_datareader.data import DataReader
from arch import arch_model

x = DataReader(
    "MORTGAGE30US",
    "fred",
    start="2010-01-01",
    end="2025-12-31",
)["MORTGAGE30US"].dropna()

y = x.diff().dropna()

model = arch_model(
    y,
    mean="ARX",
    lags=2,
    vol="EGARCH",
    p=1,
    o=0,
    q=1,
    dist="normal",
    rescale=False,
)

res = model.fit(disp="off")

print(res.params)

alpha1 = res.params["alpha[1]"]
beta1 = res.params["beta[1]"]

print(round(alpha1, 3))
print(round(beta1, 3))
# Out:
# Const           -0.003809
# MORT...0US[1]    0.112886
# MORT...0US[2]    0.072133
# omega           -0.200886
# alpha[1]         0.247284
# beta[1]          0.957708
# Name: params, dtype: float64
# 0.247
# 0.958
